# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import yfinance as yf

df=yf.download("^NSEI",start="2015-01-01", end="2025-01-01")
df.head()

df.to_csv("NIFTY50.csv")
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
df.isnull().sum()

df.head()
# the dates are in the index, not a column – reset the index first
df = df.reset_index()
df["Date"] = pd.to_datetime(df["Date"])
df["Close"].max()
df["Close"].min()
# Out:
# Ticker
# ^NSEI    6970.600098
# dtype: float64

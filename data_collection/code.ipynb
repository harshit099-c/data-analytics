# %% [markdown]
# API calling

# %%
import requests

url="https://api.artic.edu/api/v1/artworks"
res=requests.get(url)

# %%
data=res.json()
data
# Out:
# {'pagination': {'total': 130918,
#   'limit': 12,
#   'offset': 0,
#   'total_pages': 10910,
#   'current_page': 1,
#   'next_url': 'https://api.artic.edu/api/v1/artworks?page=2'},
#  'data': [{'id': 282463,
#    'api_model': 'artworks',
#    'api_link': 'https://api.artic.edu/api/v1/artworks/282463',
#    'is_boosted': False,
#    'title': 'Expressions 1 (A Study of Facial Motions)',
#    'alt_titles': None,
#    'thumbnail': None,
#    'main_reference_number': '2025.914',
#    'has_not_been_viewed_much': True,
#    'boost_rank': None,
#    'date_start': 1972,
#    'date_end': 1972,
#    'date_display': '1972',
#    'date_qualifier_title': '',
#    'date_qualifier_id': None,
#    'artist_display': 'Athena Tacha\nAmerican, born Greece, 1936',
#    'place_of_origin': None,
#    'description': None,
#    'short_description': None,
#    'dimensions': '48.3 × 73.7 cm (19 × 29 in.)',
#    'dimensions_detail': [{'depth': None,
#      'width': 73,
#      'height': 48,
#      'diameter': None,
#      'clarification': None}],
#    'medium_display': 'Letterpress halftone print',
#    'inscriptions': None,
#    'credit_line': 'Gift of the artist',
#    'catalogue_display': None,
#    'publication_history': None,
#    'exhibition_history': None,
#    'provenance_text': None,
#    'edition': 'edition of 500',
#    'publishing_verification_level': 'Web Basic',
#    'internal_department_id': 20,
#    'fiscal_year': 2026,
#    'fiscal_year_deaccession': None,
#    'is_public_domain': False,
#    'is_zoomable': False,
#    'max_zoom_window_size': 843,
#    'copyright_notice': None,
#    'has_multimedia_resources': False,
#    'has_educational_resources': False,
#    'has_advanced_imaging': False,
#    'colorfulness': None,
#    'color': None,
#    'latitude': None,
#    'longitude': None,
#    'latlon': None,
#    'is_on_view': False,
#    'on_loan_display': None,
#    'gallery_title': None,
#    'gallery_id': None,
#    'nomisma_id': None,
#    'artwork_type_title': 'Photograph',
#    'artwork_type_id': 2,
#    'department_title': 'Photography and Media',
#    'department_id': 'PC-12',
#    'artist_id': 58791,
#    'artist_title': 'Athena Tacha',
#    'alt_artist_ids': [],
#    'artist_ids': [58791],
#    'artist_titles': ['Athena Tacha'],
#    'category_ids': ['PC-12'],
#    'category_titles': ['Photography and Media'],
#    'term_titles': [],
#    'style_id': None,
#    'style_title': None,
#    'alt_style_ids': [],
#    'style_ids': [],
#    'style_titles': [],
#    'classification_id': None,
#    'classification_title': None,
#    'alt_classification_ids': [],
#    'classification_ids': [],
#    'classification_titles': [],
#    'subject_id': None,
#    'alt_subject_ids': [],
#    'subject_ids': [],
#    'subject_titles': [],
#    'material_id': None,
#    'alt_material_ids': [],
#    'material_ids': [],
#    'material_titles': [],
#    'technique_id': None,
#    'alt_technique_ids': [],
#    'technique_ids': [],
#    'technique_titles': [],
#    'theme_titles': [],
#    'image_id': None,
#    'alt_image_ids': [],
#    'document_ids': [],
#    'sound_ids': [],
#    'video_ids': [],
#    'text_ids': [],
#    'section_ids': [],
#    'section_titles': [],
#    'site_ids': [],
#    'suggest_autocomplete_all': [{'input': ['2025.914'],
#      'contexts': {'groupings': ['accession']}},
#     {'input': ['Expressions 1 (A Study of Facial Motions)'],
#      'weight': 1,
#      'contexts': {'groupings': ['title']}}],
#    'source_updated_at': '2026-02-17T12:55:56-06:00',
#    'updated_at': '2026-02-17T13:00:30-06:00',
#    'timestamp': '2026-02-17T13:05:47-06:00'},
#   {'id': 283047,
#    'api_model': 'artworks',
#    'api_link': 'https://api.artic.edu/api/v1/artworks/283047',
#    'is_boosted': False,
#    'title': 'Ten Projects for Staircases',
#    'alt_titles': None,
#    'thumbnail': None,
#    'main_reference_number': '2025.921',
#    'has_not_been_viewed_much': True,
#    'boost_rank': None,
#    'date_start': 1973,
#    'date_end': 1973,
#    'date_display': '1973',
#    'date_qualifier_title': '',
#    'date_qualifier_id': None,
#    'artist_display': 'Athena Tacha\nAmerican, born Greece 1936',
#    'place_of_origin': None,
#    'description': None,
#    'short_description': None,
#    'dimensions': '20.4 × 14 cm (8 × 5 1/2 in.)',
#    'dimensions_detail': [{'depth': None,
#      'width': 14,
#      'height': 20,
#      'diameter': None,
#      'clarification': None}],
#    'medium_display': 'Letterpress halftone print',
#    'inscriptions': None,
#    'credit_line': 'Gift of the artist',
#    'catalogue_display': None,
#    'publication_history': None,
#    'exhibition_history': None,
#    'provenance_text': None,
#    'edition': None,
#    'publishing_verification_level': 'Web Basic',
#    'internal_department_id': 20,
#    'fiscal_year': 2026,
#    'fiscal_year_deaccession': None,
#    'is_public_domain': False,
#    'is_zoomable': False,
#    'max_zoom_window_size': 843,
#    'copyright_notice': None,
#    'has_multimedia_resources': False,
#    'has_educational_resources': False,
#    'has_advanced_imaging': False,
#    'colorfulness': None,
#    'color': None,
#    'latitude': None,
#    'longitude': None,
#    'latlon': None,
#    'is_on_view': False,
#    'on_loan_display': None,
#    'gallery_title': None,
#    'gallery_id': None,
#    'nomisma_id': None,
#    'artwork_type_title': 'Print',
#    'artwork_type_id': 18,
#    'department_title': 'Photography and Media',
#    'department_id': 'PC-12',
#    'artist_id': 58791,
#    'artist_title': 'Athena Tacha',
#    'alt_artist_ids': [],
#    'artist_ids': [58791],
#    'artist_titles': ['Athena Tacha'],
#    'category_ids': ['PC-12'],
#    'category_titles': ['Photography and Media'],
#    'term_titles': [],
#    'style_id': None,
#    'style_title': None,
#    'alt_style_ids': [],
#    'style_ids': [],
#    'style_titles': [],
#    'classification_id': None,
#    'classification_title': None,
#    'alt_classification_ids': [],
#    'classification_ids': [],
#    'classification_titles': [],
#    'subject_id': None,
#    'alt_subject_ids': [],
#    'subject_ids': [],
#    'subject_titles': [],
#    'material_id': None,
#    'alt_material_ids': [],
#    'material_ids': [],
#    'material_titles': [],
#    'technique_id': None,
#    'alt_technique_ids': [],
#    'technique_ids': [],
#    'technique_titles': [],
#    'theme_titles': [],
#    'image_id': None,
#    'alt_image_ids': [],
#    'document_ids': [],
#    'sound_ids': [],
#    'video_ids': [],
#    'text_ids': [],
#    'section_ids': [],
#    'section_titles': [],
#    'site_ids': [],
#    'suggest_autocomplete_all': [{'input': ['2025.921'],
#      'contexts': {'groupings': ['accession']}},
#     {'input': ['Ten Projects for Staircases'],
#      'weight': 1,
#      'contexts': {'groupings': ['title']}}],
#    'source_updated_at': '2026-02-17T12:55:09-06:00',
#    'updated_at': '2026-02-17T12:55:18-06:00',
#    'timestamp': '2026-02-17T13:05:47-06:00'},
#   {'id': 283046,
#    'api_model': 'artworks',
#    'api_link': 'https://api.artic.edu/api/v1/artworks/283046',
#    'is_boosted': False,
#    'title': 'Gestures #1 (A Study of Finger Positions)',
#    'alt_titles': None,
#    'thumbnail': None,
#    'main_reference_number': '2025.920',
#    'has_not_been_viewed_much': True,
#    'boost_rank': None,
#    'date_start': 1973,
#    'date_end': 1973,
#    'date_display': '1973',
#    'date_qualifier_title': '',
#    'date_qualifier_id': None,
#    'artist_display': 'Athena Tacha\nAmerican, born Greece 1936',
#    'place_of_origin': None,
#    'description': None,
#    'short_description': None,
#    'dimensions': '61 × 78.8 cm (24 × 31 in.)',
#    'dimensions_detail': [{'depth': None,
#      'width': 78,
#      'height': 61,
#      'diameter': None,
#      'clarification': None}],
#    'medium_display': 'Offset lithograph',
#    'inscriptions': None,
#    'credit_line': 'Gift of the artist',
#    'catalogue_display': None,
#    'publication_history': None,
#    'exhibition_history': None,
#    'provenance_text': None,
#    'edition': 'edition of 500',
#    'publishing_verification_level': 'Web Basic',
#    'internal_department_id': 20,
#    'fiscal_year': 2026,
#    'fiscal_year_deaccession': None,
#    'is_public_domain': False,
#    'is_zoomable': False,
#    'max_zoom_window_size': 843,
#    'copyright_notice': None,
#    'has_multimedia_resources': False,
#    'has_educational_resources': False,
#    'has_advanced_imaging': False,
#    'colorfulness': None,
#    'color': None,
#    'latitude': None,
#    'longitude': None,
#    'latlon': None,
#    'is_on_view': False,
#    'on_loan_display': None,
#    'gallery_title': None,
#    'gallery_id': None,
#    'nomisma_id': None,
#    'artwork_type_title': 'Print',
#    'artwork_type_id': 18,
#    'department_title': 'Photography and Media',
#    'department_id': 'PC-12',
#    'artist_id': 58791,
#    'artist_title': 'Athena Tacha',
#    'alt_artist_ids': [],
#    'artist_ids': [58791],
#    'artist_titles': ['Athena Tacha'],
#    'category_ids': ['PC-12'],
#    'category_titles': ['Photography and Media'],
#    'term_titles': [],
#    'style_id': None,
#    'style_title': None,
#    'alt_style_ids': [],
#    'style_ids': [],
#    'style_titles': [],
#    'classification_id': None,
#    'classification_title': None,
#    'alt_classification_ids': [],
#    'classification_ids': [],
#    'classification_titles': [],
#    'subject_id': None,
#    'alt_subject_ids': [],
#    'subject_ids': [],
#    'subject_titles': [],
#    'material_id': None,
#    'alt_material_ids': [],
#    'material_ids': [],
#    'material_titles': [],
#    'technique_id': None,
#    'alt_technique_ids': [],
#    'technique_ids': [],
#    'technique_titles': [],
#    'theme_titles': [],
#    'image_id': None,
#    'alt_image_ids': [],
#    'document_ids': [],
#    'sound_ids': [],
#    'video_ids': [],
#    'text_ids': [],
#    'section_ids': [],
#    'section_titles': [],
#    'site_ids': [],
#    'suggest_autocomplete_all': [{'input': ['2025.920'],
#      'contexts': {'groupings': ['accession']}},
#     {'input': ['Gestures #1 (A Study of Finger Positions)'],
#      'weight': 1,
#      'contexts': {'groupings': ['title']}}],
#    'source_updated_at': '2026-02-17T12:54:10-06:00',
#    'updated_at': '2026-02-17T12:55:18-06:00',
#    'timestamp': '2026-02-17T13:05:47-06:00'},
#   {'id': 190181,
#    'api_model': 'artworks',
#    'api_link': 'https://api.artic.edu/api/v1/artworks/190181',
#    'is_boosted': False,
#    'title': 'River City II, Chicago, Illinois, Perspective Sketch',
#    'alt_titles': None,
#    'thumbnail': {'lqip': '...',
#     'width': 5160,
#     'height': 3135,
#     'alt_text': 'A work made of marker on tracing paper.'},
#    'main_reference_number': 'RX23664/110.283',
#    'has_not_been_viewed_much': False,
#    'boost_rank': None,
#    'date_start': 1979,
#    'date_end': 1979,
#    'date_display': '1979',
#    'date_qualifier_title': 'Designed',
#    'date_qualifier_id': 2,
#    'artist_display': 'Bertrand Goldberg\nAmerican, 1913-1997',
#    'place_of_origin': 'Chicago',
#    'description': None,
#    'short_description': None,
#    'dimensions': '45.6 × 89.6 cm (18 × 35 5/16 in.)',
#    'dimensions_detail': [{'depth': None,
#      'width': 89,
#      'height': 45,
#      'diameter': None,
#      'clarification': None}],
#    'medium_display': 'Marker on tracing paper',
#    'inscriptions': None,
#    'credit_line': 'The Archive of Bertrand Goldberg, gifted by his children through his estate',
#    'catalogue_display': None,
#    'publication_history': 'Barrow, Heather and Lori Hanna Boyer.  Bertrand Goldberg Collection Finding Aid.  (The Art Institute of Chicago, 2007), p. 36.',
#    'exhibition_history': None,
#    'provenance_text': None,
#    'edition': None,
#    'publishing_verification_level': 'Web Cataloged',
#    'internal_department_id': 25,
#    'fiscal_year': None,
#    'fiscal_year_deaccession': None,
#    'is_public_domain': False,
#    'is_zoomable': True,
#    'max_zoom_window_size': -1,
#    'copyright_notice': None,
#    'has_multimedia_resources': False,
#    'has_educational_resources': False,
#    'has_advanced_imaging': False,
#    'colorfulness': 7.4231,
#    'color': {'h': 38,
#     'l': 47,
#     's': 8,
#     'percentage': 0.7592396945432978,
#     'population': 3277},
#    'latitude': None,
#    'longitude': None,
#    'latlon': None,
#    'is_on_view': False,
#    'on_loan_display': None,
#    'gallery_title': None,
#    'gallery_id': None,
#    'nomisma_id': None,
#    'artwork_type_title': 'Architectural Drawing',
#    'artwork_type_id': 34,
#    'department_title': 'Architecture and Design',
#    'department_id': 'PC-5',
#    'artist_id': 31299,
#    'artist_title': 'Bertrand Goldberg',
#    'alt_artist_ids': [],
#    'artist_ids': [31299],
#    'artist_titles': ['Bertrand Goldberg'],
#    'category_ids': ['PC-5', 'PC-154'],
#    'category_titles': ['Architecture and Design', 'Chicago Artists'],
#    'term_titles': ['architectural drawing',
#     'paper (fiber product)',
#     'Chicago',
#     'Bertrand Goldberg Archive'],
#    'style_id': None,
#    'style_title': None,
#    'alt_style_ids': [],
#    'style_ids': [],
#    'style_titles': [],
#    'classification_id': 'TM-126',
#    'classification_title': 'architectural drawing',
#    'alt_classification_ids': [],
#    'classification_ids': ['TM-126'],
#    'classification_titles': ['architectural drawing'],
#    'subject_id': None,
#    'alt_subject_ids': ['TM-12075', 'TM-14001'],
#    'subject_ids': ['TM-12075', 'TM-14001'],
#    'subject_titles': ['Chicago', 'Bertrand Goldberg Archive'],
#    'material_id': 'TM-2982',
#    'alt_material_ids': [],
#    'material_ids': ['TM-2982'],
#    'material_titles': ['paper (fiber product)'],
#    'technique_id': None,
#    'alt_technique_ids': [],
#    'technique_ids': [],
#    'technique_titles': [],
#    'theme_titles': ['Chicago Artists'],
#    'image_id': 'ff692b35-8815-f393-d975-7f289508fe67',
#    'alt_image_ids': [],
#    'document_ids': [],
#    'sound_ids': [],
#    'video_ids': [],
#    'text_ids': [],
#    'section_ids': [],
#    'section_titles': [],
#    'site_ids': [],
#    'suggest_autocomplete_all': [{'input': ['RX23664/110.283'],
#      'contexts': {'groupings': ['accession']}},
#     {'input': ['River City II, Chicago, Illinois, Perspective Sketch'],
#      'weight': 238,
#      'contexts': {'groupings': ['title']}}],
#    'source_updated_at': '2026-02-17T12:51:26-06:00',
#    'updated_at': '2026-02-17T12:55:18-06:00',
#    'timestamp': '2026-02-17T13:05:47-06:00'},
#   {'id': 212578,
#    'api_model': 'artworks',
#    'api_link': 'https://api.artic.edu/api/v1/artworks/212578',
#    'is_boosted': False,
#    'title': 'River City I: Pedestrian Park Level Plan',
#    'alt_titles': None,
#    'thumbnail': {'lqip': '...',
#     'width': 3000,
#     'height': 1685,
#     'alt_text': 'A work made of zip-a-tone, colored pencil, film collage, and sepia print on paper.'},
#    'main_reference_number': 'RX23664/110.198',
#    'has_not_been_viewed_much': True,
#    'boost_rank': None,
#    'date_start': 1969,
#    'date_end': 1979,
#    'date_display': 'c. 1974',
#    'date_qualifier_title': 'Designed',
#    'date_qualifier_id': 2,
#    'artist_display': 'Bertrand Goldberg\nAmerican, 1913-1997',
#    'place_of_origin': 'Chicago',
#    'description': None,
#    'short_description': None,
#    'dimensions': None,
#    'dimensions_detail': [],
#    'medium_display': 'Zip-a-tone, colored pencil, film collage, and sepia print on paper',
#    'inscriptions': None,
#    'credit_line': 'The Archive of Bertrand Goldberg, gifted by his children through his estate',
#    'catalogue_display': None,
#    'publication_history': None,
#    'exhibition_history': None,
#    'provenance_text': None,
#    'edition': None,
#    'publishing_verification_level': 'Web Basic',
#    'internal_department_id': 25,
#    'fiscal_year': None,
#    'fiscal_year_deaccession': None,
#    'is_public_domain': False,
#    'is_zoomable': True,
#    'max_zoom_window_size': -1,
#    'copyright_notice': None,
#    'has_multimedia_resources': False,
#    'has_educational_resources': False,
#    'has_advanced_imaging': False,
#    'colorfulness': 55.6275,
#    'color': {'h': 45,
#     'l': 55,
#     's': 84,
#     'percentage': 0.05918658571145536,
#     'population': 236},
#    'latitude': None,
#    'longitude': None,
#    'latlon': None,
#    'is_on_view': False,
#    'on_loan_display': None,
#    'gallery_title': None,
#    'gallery_id': None,
#    'nomisma_id': None,
#    'artwork_type_title': 'Architectural Drawing',
#    'artwork_type_id': 34,
#    'department_title': 'Architecture and Design',
#    'department_id': 'PC-5',
#    'artist_id': 31299,
#    'artist_title': 'Bertrand Goldberg',
#    'alt_artist_ids': [],
#    'artist_ids': [31299],
#    'artist_titles': ['Bertrand Goldberg'],
#    'category_ids': ['PC-5'],
#    'category_titles': ['Architecture and Design'],
#    'term_titles': ['paper (fiber product)',
#     'screentone',
#     'communities',
#     'Chicago',
#     'commerical',
#     'architectural drawing',
#     'Bertrand Goldberg Archive'],
#    'style_id': None,
#    'style_title': None,
#    'alt_style_ids': [],
#    'style_ids': [],
#    'style_titles': [],
#    'classification_id': 'TM-12046',
#    'classification_title': 'screentone',
#    'alt_classification_ids': ['TM-126'],
#    'classification_ids': ['TM-12046', 'TM-126'],
#    'classification_titles': ['screentone', 'architectural drawing'],
#    'subject_id': 'TM-12093',
#    'alt_subject_ids': ['TM-12075', 'TM-12092', 'TM-14001'],
#    'subject_ids': ['TM-12093', 'TM-12075', 'TM-12092', 'TM-14001'],
#    'subject_titles': ['communities',
#     'Chicago',
#     'commerical',
#     'Bertrand Goldberg Archive'],
#    'material_id': 'TM-2982',
#    'alt_material_ids': [],
#    'material_ids': ['TM-2982'],
#    'material_titles': ['paper (fiber product)'],
#    'technique_id': None,
#    'alt_technique_ids': [],
#    'technique_ids': [],
#    'technique_titles': [],
#    'theme_titles': [],
#    'image_id': 'c0155e7d-cef2-f2e7-efd0-6c724963ddac',
#    'alt_image_ids': [],
#    'document_ids': [],
#    'sound_ids': [],
#    'video_ids': [],
#    'text_ids': [],
#    'section_ids': [],
#    'section_titles': [],
#    'site_ids': [],
#    'suggest_autocomplete_all': [{'input': ['RX23664/110.198'],
#      'contexts': {'groupings': ['accession']}},
#     {'input': ['River City I: Pedestrian Park Level Plan'],
#      'weight': 91,
#      'contexts': {'groupings': ['title']}}],
#    'source_updated_at': '2026-02-17T12:49:49-06:00',
#    'updated_at': '2026-02-17T12:50:28-06:00',
#    'timestamp': '2026-02-17T13:05:47-06:00'},
#   {'id': 212576,
#    'api_model': 'artworks',
#    'api_link': 'https://api.artic.edu/api/v1/artworks/212576',
#    'is_boosted': False,
#    'title': 'River City I: Industrial Level Plan',
#    'alt_titles': None,
#    'thumbnail': {'lqip': '...',
#     'width': 3000,
#     'height': 1784,
#     'alt_text': 'A work made of zip-a-tone, colored pencil, film collage, and sepia print on paper.'},
#    'main_reference_number': 'RX23664/110.195',
#    'has_not_been_viewed_much': True,
#    'boost_rank': None,
#    'date_start': 1969,
#    'date_end': 1979,
#    'date_display': 'c. 1974',
#    'date_qualifier_title': 'Designed',
#    'date_qualifier_id': 2,
#    'artist_display': 'Bertrand Goldberg\nAmerican, 1913-1997',
#    'place_of_origin': 'Chicago',
#    'description': None,
#    'short_description': None,
#    'dimensions': None,
#    'dimensions_detail': [],
#    'medium_display': 'Zip-a-tone, colored pencil, film collage, and sepia print on paper',
#    'inscriptions': None,
#    'credit_line': 'The Archive of Bertrand Goldberg, gifted by his children through his estate',
#    'catalogue_display': None,
#    'publication_history': None,
#    'exhibition_history': None,
#    'provenance_text': None,
#    'edition': None,
#    'publishing_verification_level': 'Web Basic',
#    'internal_department_id': 25,
#    'fiscal_year': None,
#    'fiscal_year_deaccession': None,
#    'is_public_domain': False,
#    'is_zoomable': True,
#    'max_zoom_window_size': -1,
#    'copyright_notice': None,
#    'has_multimedia_resources': False,
#    'has_educational_resources': False,
#    'has_advanced_imaging': False,
#    'colorfulness': 42.8438,
#    'color': {'h': 23,
#     'l': 50,
#     's': 87,
#     'percentage': 0.00497226188193009,
#     'population': 21},
#    'latitude': None,
#    'longitude': None,
#    'latlon': None,
#    'is_on_view': False,
#    'on_loan_display': None,
#    'gallery_title': None,
#    'gallery_id': None,
#    'nomisma_id': None,
#    'artwork_type_title': 'Architectural Drawing',
#    'artwork_type_id': 34,
#    'department_title': 'Architecture and Design',
#    'department_id': 'PC-5',
#    'artist_id': 31299,
#    'artist_title': 'Bertrand Goldberg',
#    'alt_artist_ids': [],
#    'artist_ids': [31299],
#    'artist_titles': ['Bertrand Goldberg'],
#    'category_ids': ['PC-5'],
#    'category_titles': ['Architecture and Design'],
#    'term_titles': ['paper (fiber product)',
#     'screentone',
#     'communities',
#     'Chicago',
#     'commerical',
#     'architectural drawing',
#     'Bertrand Goldberg Archive'],
#    'style_id': None,
#    'style_title': None,
#    'alt_style_ids': [],
#    'style_ids': [],
#    'style_titles': [],
#    'classification_id': 'TM-12046',
#    'classification_title': 'screentone',
#    'alt_classification_ids': ['TM-126'],
#    'classification_ids': ['TM-12046', 'TM-126'],
#    'classification_titles': ['screentone', 'architectural drawing'],
#    'subject_id': 'TM-12093',
#    'alt_subject_ids': ['TM-12075', 'TM-12092', 'TM-14001'],
#    'subject_ids': ['TM-12093', 'TM-12075', 'TM-12092', 'TM-14001'],
#    'subject_titles': ['communities',
#     'Chicago',
#     'commerical',
#     'Bertrand Goldberg Archive'],
#    'material_id': 'TM-2982',
#    'alt_material_ids': [],
#    'material_ids': ['TM-2982'],
#    'material_titles': ['paper (fiber product)'],
#    'technique_id': None,
#    'alt_technique_ids': [],
#    'technique_ids': [],
#    'technique_titles': [],
#    'theme_titles': [],
#    'image_id': '813b2f97-3618-8d80-20de-c6fdcecde422',
#    'alt_image_ids': [],
#    'document_ids': [],
#    'sound_ids': [],
#    'video_ids': [],
#    'text_ids': [],
#    'section_ids': [],
#    'section_titles': [],
#    'site_ids': [],
#    'suggest_autocomplete_all': [{'input': ['RX23664/110.195'],
#      'contexts': {'groupings': ['accession']}},
#     {'input': ['River City I: Industrial Level Plan'],
#      'weight': 60,
#      'contexts': {'groupings': ['title']}}],
#    'source_updated_at': '2026-02-17T12:48:53-06:00',
#    'updated_at': '2026-02-17T12:50:28-06:00',
#    'timestamp': '2026-02-17T13:05:47-06:00'},
#   {'id': 278628,
#    'api_model': 'artworks',
#    'api_link': 'https://api.artic.edu/api/v1/artworks/278628',
#    'is_boosted': False,
#    'title': 'Untitled (Jinete with Red Shirt No. 3)\u200b',
#    'alt_titles': None,
#    'thumbnail': {'lqip': '...',
#     'width': 8320,
#     'height': 9906,
#     'alt_text': 'A work made of graphite, tempera, and crayon on two sheets of cream wove paper, pieced.'},
#    'main_reference_number': '2025.1002',
#    'has_not_been_viewed_much': True,
#    'boost_rank': None,
#    'date_start': 1950,
#    'date_end': 1955,
#    'date_display': '1950-55',
#    'date_qualifier_title': '',
#    'date_qualifier_id': None,
#    'artist_display': 'Martin Ramirez\nAmerican, born Mexico, 1895-1960',
#    'place_of_origin': 'United States',
#    'description': None,
#    'short_description': None,
#    'dimensions': '72.5 × 61 cm (28 9/16 × 24 1/16 in.)',
#    'dimensions_detail': [{'depth': None,
#      'width': 61,
#      'height': 72,
#      'diameter': None,
#      'clarification': None}],
#    'medium_display': 'Graphite, tempera, and crayon on two sheets of cream wove paper, pieced',
#    'inscriptions': None,
#    'credit_line': 'Gift of Richard and Ellen Sandor',
#    'catalogue_display': None,
#    'publication_history': None,
#    'exhibition_history': None,
#    'provenance_text': None,
#    'edition': None,
#    'publishing_verification_level': 'Web Basic',
#    'internal_department_id': 3,
#    'fiscal_year': 2026,
#    'fiscal_year_deaccession': None,
#    'is_public_domain': False,
#    'is_zoomable': False,
#    'max_zoom_window_size': 843,
#    'copyright_notice': None,
#    'has_multimedia_resources': False,
#    'has_educational_resources': False,
#    'has_advanced_imaging': False,
#    'colorfulness': 0,
#    'color': {'h': 6,
#     'l': 53,
#     's': 19,
#     'percentage': 0.0004877580021432232,
#     'population': 402},
#    'latitude': None,
#    'longitude': None,
#    'latlon': None,
#    'is_on_view': False,
#    'on_loan_display': None,
#    'gallery_title': None,
#    'gallery_id': None,
#    'nomisma_id': None,
#    'artwork_type_title': 'Drawing and Watercolor',
#    'artwork_type_id': 14,
#    'department_title': 'Prints and Drawings',
#    'department_id': 'PC-13',
#    'artist_id': 55602,
#    'artist_title': 'Martin Ramirez',
#    'alt_artist_ids': [],
#    'artist_ids': [55602],
#    'artist_titles': ['Martin Ramirez'],
#    'category_ids': ['PC-13'],
#    'category_titles': ['Prints and Drawings'],
#    'term_titles': ['prints and drawing',
#     'paper',
#     'crayon',
#     'tempera',
#     'graphite',
#     'drawing'],
#    'style_id': None,
#    'style_title': None,
#    'alt_style_ids': [],
#    'style_ids': [],
#    'style_titles': [],
#    'classification_id': 'TM-4',
#    'classification_title': 'prints and drawing',
#    'alt_classification_ids': ['TM-145',
#     'TM-23',
#     'TM-153',
#     'TM-175',
#     'TM-14658'],
#    'classification_ids': ['TM-4',
#     'TM-145',
#     'TM-23',
#     'TM-153',
#     'TM-175',
#     'TM-14658'],
#    'classification_titles': ['prints and drawing',
#     'paper',
#     'crayon',
#     'tempera',
#     'graphite',
#     'drawing'],
#    'subject_id': None,
#    'alt_subject_ids': [],
#    'subject_ids': [],
#    'subject_titles': [],
#    'material_id': None,
#    'alt_material_ids': [],
#    'material_ids': [],
#    'material_titles': [],
#    'technique_id': None,
#    'alt_technique_ids': [],
#    'technique_ids': [],
#    'technique_titles': [],
#    'theme_titles': [],
#    'image_id': '21df238f-45fb-c2d9-0e23-54bb855e6175',
#    'alt_image_ids': [],
#    'document_ids': [],
#    'sound_ids': [],
#    'video_ids': [],
#    'text_ids': [],
#    'section_ids': [],
#    'section_titles': [],
#    'site_ids': [],
#    'suggest_autocomplete_all': [{'input': ['2025.1002'],
#      'contexts': {'groupings': ['accession']}},
#     {'input': ['Untitled (Jinete with Red Shirt No. 3)\u200b'],
#      'weight': 1,
#      'contexts': {'groupings': ['title']}}],
#    'source_updated_at': '2026-02-17T12:49:52-06:00',
#    'updated_at': '2026-02-17T12:50:27-06:00',
#    'timestamp': '2026-02-17T13:05:47-06:00'},
#   {'id': 278593,
#    'api_model': 'artworks',
#    'api_link': 'https://api.artic.edu/api/v1/artworks/278593',
#    'is_boosted': False,
#    'title': 'Untitled (Two Figures, Female Figure Pointing)',
#    'alt_titles': None,
#    'thumbnail': {'lqip': '...',
#     'width': 8323,
#     'height': 9518,
#     'alt_text': 'A work made of graphite and opaque watercolor on brown cardboard.'},
#    'main_reference_number': '2025.1003',
#    'has_not_been_viewed_much': True,
#    'boost_rank': None,
#    'date_start': 1939,
#    'date_end': 1942,
#    'date_display': '1939-42',
#    'date_qualifier_title': '',
#    'date_qualifier_id': None,
#    'artist_display': 'Bill Traylor\nAmerican, c. 1853–1949',
#    'place_of_origin': 'United States',
#    'description': None,
#    'short_description': None,
#    'dimensions': '38.2 × 33.3 cm (15 1/16 × 13 1/8 in.)',
#    'dimensions_detail': [{'depth': None,
#      'width': 33,
#      'height': 38,
#      'diameter': None,
#      'clarification': None}],
#    'medium_display': 'Graphite and opaque watercolor on brown cardboard',
#    'inscriptions': None,
#    'credit_line': 'Gift of Richard and Ellen Sandor',
#    'catalogue_display': None,
#    'publication_history': None,
#    'exhibition_history': None,
#    'provenance_text': None,
#    'edition': None,
#    'publishing_verification_level': 'Web Basic',
#    'internal_department_id': 3,
#    'fiscal_year': 2026,
#    'fiscal_year_deaccession': None,
#    'is_public_domain': False,
#    'is_zoomable': False,
#    'max_zoom_window_size': 843,
#    'copyright_notice': None,
#    'has_multimedia_resources': False,
#    'has_educational_resources': False,
#    'has_advanced_imaging': False,
#    'colorfulness': 0,
#    'color': {'h': 5,
#     'l': 42,
#     's': 39,
#     'percentage': 0.0001136100927368891,
#     'population': 90},
#    'latitude': None,
#    'longitude': None,
#    'latlon': None,
#    'is_on_view': False,
#    'on_loan_display': None,
#    'gallery_title': None,
#    'gallery_id': None,
#    'nomisma_id': None,
#    'artwork_type_title': 'Drawing and Watercolor',
#    'artwork_type_id': 14,
#    'department_title': 'Prints and Drawings',
#    'department_id': 'PC-13',
#    'artist_id': 59259,
#    'artist_title': 'Bill Traylor',
#    'alt_artist_ids': [],
#    'artist_ids': [59259],
#    'artist_titles': ['Bill Traylor'],
#    'category_ids': ['PC-13'],
#    'category_titles': ['Prints and Drawings'],
#    'term_titles': ['prints and drawing',
#     'cardboard',
#     'gouache',
#     'graphite',
#     'drawing'],
#    'style_id': None,
#    'style_title': None,
#    'alt_style_ids': [],
#    'style_ids': [],
#    'style_titles': [],
#    'classification_id': 'TM-4',
#    'classification_title': 'prints and drawing',
#    'alt_classification_ids': ['TM-15895', 'TM-221', 'TM-175', 'TM-14658'],
#    'classification_ids': ['TM-4', 'TM-15895', 'TM-221', 'TM-175', 'TM-14658'],
#    'classification_titles': ['prints and drawing',
#     'cardboard',
#     'gouache',
#     'graphite',
#     'drawing'],
#    'subject_id': None,
#    'alt_subject_ids': [],
#    'subject_ids': [],
#    'subject_titles': [],
#    'material_id': None,
#    'alt_material_ids': [],
#    'material_ids': [],
#    'material_titles': [],
#    'technique_id': None,
#    'alt_technique_ids': [],
#    'technique_ids': [],
#    'technique_titles': [],
#    'theme_titles': [],
#    'image_id': '7a18e0eb-afe2-63a1-1246-8fb014204beb',
#    'alt_image_ids': [],
#    'document_ids': [],
#    'sound_ids': [],
#    'video_ids': [],
#    'text_ids': [],
#    'section_ids': [],
#    'section_titles': [],
#    'site_ids': [],
#    'suggest_autocomplete_all': [{'input': ['2025.1003'],
#      'contexts': {'groupings': ['accession']}},
#     {'input': ['Untitled (Two Figures, Female Figure Pointing)'],
#      'weight': 1,
#      'contexts': {'groupings': ['title']}}],
#    'source_updated_at': '2026-02-17T12:42:21-06:00',
#    'updated_at': '2026-02-17T12:45:18-06:00',
#    'timestamp': '2026-02-17T13:05:47-06:00'},
#   {'id': 44892,
#    'api_model': 'artworks',
#    'api_link': 'https://api.artic.edu/api/v1/artworks/44892',
#    'is_boosted': True,
#    'title': 'Fish (Still Life)',
#    'alt_titles': None,
#    'thumbnail': {'lqip': '...',
#     'width': 16704,
#     'height': 13234,
#     'alt_text': 'Still-life painting, fish, open oysters, eel, lemon on tablecloth.'},
#    'main_reference_number': '1942.311',
#    'has_not_been_viewed_much': False,
#    'boost_rank': None,
#    'date_start': 1864,
#    'date_end': 1864,
#    'date_display': '1864',
#    'date_qualifier_title': '',
#    'date_qualifier_id': None,
#    'artist_display': 'Édouard Manet (French, 1832–1883)',
#    'place_of_origin': 'France',
#    'description': '<p>Although still-life ensembles were an important element in many of the major paintings of the avant-garde artist Édouard Manet, his most sustained interest in the genre itself was from 1864 to 1865, when <em>Fish</em> was painted. Manet’s focus on still lifes coincided with the gradual reacceptance of the genre during the nineteenth century, due in part to the growth of the middle class, whose tastes ran to intimate, moderately priced works. This painting, like many of Manet’s still-life compositions, recalls seventeenth-century Dutch models. The directness of execution, bold brushwork, and immediacy of vision displayed in the canvas, however, suggest why the public found Manet’s work so unorthodox and confrontational. While <em>Fish</em> is indeed an image of “dead nature” (<em>nature morte</em> is the French term for still life), there is nothing still about the work: the produce seems fresh and the handling of paint vigorous. Further enlivening the composition is the placement of the carp, which offsets the strong diagonal of the other elements. Manet never submitted his still lifes to the official French Salon but rather sold them through the burgeoning network of art galleries in Paris and gave them to friends.</p>\n',
#    'short_description': 'This painting, like many of Manet’s still lifes, recalls 17th-century Dutch models. The directness of execution, bold brushwork, and immediacy of vision, however, suggest why the public found Manet’s work so unorthodox and confrontational. While this painting depicts “dead nature” (<em>nature morte</em> is French for still life), there is nothing still about the work: the produce seems fresh and the handling of the paint vigorous.',
#    'dimensions': '73.5 × 92.4 cm (28 15/16 × 36 3/8 in.); Framed: 108.6 × 127.4 × 12.7 cm (42 3/4 × 50 1/8 × 5 in.)',
#    'dimensions_detail': [{'depth': None,
#      'width': 92,
#      'height': 73,
#      'diameter': None,
#      'clarification': None},
#     {'depth': 12,
#      'width': 127,
#      'height': 108,
#      'diameter': None,
#      'clarification': 'Framed'}],
#    'medium_display': 'Oil on canvas',
#    'inscriptions': 'Signed lower right:  Manet',
#    'credit_line': 'Mr. and Mrs. Lewis Larned Coburn Memorial Collection',
#    'catalogue_display': None,
#    'publication_history': 'Paris, Ecole Nationale des Beaux-Arts, Exposition des oeuvres d’Édouard Manet, January 1884, cat. 31.\n\nThéodore Duret, Histoire d’Édouard Manet et de son oeuvre (Paris, 1902), no. 70.\n\nThéodore Duret, Manet and the French Impressionists (London, 1910), p. 220, no. 220.\n\nAntonin Proust, Édouard Manet: Souvenirs (Paris, 1913), p. 54, no. 38.\n\nThéodore Duret, Histoire de Édouard Manet et de son oeuvre (Paris, 1926), no. 70 (ill.).\n\nÉtienne Moreau-Nelaton, Manet: Raconté par Lui-Même (Paris, 1926), vol. 1, pp. 63, 79, fig. 69, vol. 2, fig. 344.\n\nAdolphe Tabarant, Manet, Histoire Catalographique (Paris, 1931), p. 131, no. 90.\n\nPaul Jamot and Georges Wildenstein, Manet (Paris, 1932), vol. 1, p. 128, no. 96, vol. 2, p. 197, fig. 406.\n\nThéodore Duret, Manet, trans. J. E. Crawford Flitch, 1937, pl. 39 (ill.).\n\nGotthard Jedlicka, Édouard Manet (Erlenbach-Zurich, 1941), p. 197.\n\nArt News 41 (February 1, 1943), p. 31, (ill.).\n\nArt News 42 (January 1, 1944), p. 27 (ill.).\n\nF. A. Sweet, “An Important Stiff Life by Édouard Manet,” Art Institute Bulletin 38 (1944), pp. 35–37 (ill.).\n\nThe Art Institute of Chicago, Masterpiece of the Month: Notes and Bibliography, (February 1944), pp. 82, 83.\n\nThe Art Institute of Chicago, An Illustrated Guide to the Collection of The Art Institute of Chicago (Chicago, 1945), pp. 36-37 (ill.). \n\nA. Tabarant, Manet et ses oeuvres (Paris, 1947), pp. 97, 98, 518, 535, 605, no. 90 (ill.).\n\nJ.-L. Vaudoyer, E. Manet (Paris, 1955), pl. 20.\n\nThe Art Institute of Chicago, A Brief Guide to the Collections (Chicago, 1956), pp. 32 (ill.), 35.\n\nThe Art Institute of Chicago, Paintings in The Art Institute of Chicago: A Catalogue of the Picture Collection, 1961, pp. 267–268.\n\nPierre Courthion, Édouard Manet (New York, 1962), pp. 84–85.\n\nPhoebe Pool and Sandra Orienti, The Complete Paintings of Manet (New York, 1967), pl. VIb.\n\nJohn Maxon, The Art Institute of Chicago (New York, 1970), pp. 77 (ill.).\n\nDenis Rouart and Daniel Wildenstein, Edouard Manet: Catalogue raisonné: Peintures vol. 1 (Paris, 1975), no. 80 (ill.).\n\nAnne Coffin Hanson, Manet and the Modern Tradition (New York, 1977), p. 70, pl. 27.\n\nThe Art Institute of Chicago 100 Masterpieces (Chicago, 1978), p. 85, no. 43 (ill.).\n\nGabriel P. Weisberg and William S. Talbot, Chardin and the Still-Life Tradition in France (Cleveland, 1979), p. 39, fig. 26.\n\nRichard R. Brettell, French Salon Artists 1800-1900 (Chicago, 1987), pp. 55-56 (ill.).\n\nKathleen Adler, Manet (Oxford, 1986), pp. 189–191, fig. 179.\n\nJ. Patrice Marandel, “A Note on Bazille’s ‘Still Life with Fish,’” Bulletin of the Detroit Institute of Arts 65, 4 (1990), p. 6, 7, 11, fig.2, no. 8.\n\nFrédéric Bazille exh. cat. (Montpellier, Musée Fabre and New York, The Brooklyn Museum, 1992), p. 93, under cat. 12.\n\nManuela B. Mena Marqués, ed., Manet en el Prado (Madrid, Museo National del Prado, 2003-4), p. 222 (ill.), under cat. 59.\n\nThe Age of Impressionism at the Art Institute of Chicago (New Haven and London, 2008), cat. 1, pp. 28–29 (ill.).\n\n“Manet, Cat. 2, Fish (Still Life),” in Manet Paintings and Works on Paper at the Art Institute of Chicago (Art Institute of Chicago, 2017), <a href="https://publications.artic.edu/manet/reader/manetart/section/140020">https://publications.artic.edu/manet/reader/manetart/section/140020</a>.\n\nJames Ensor: In Your Wildest Dreams; Beyond Impressionism, exh. cat. (Antwerp: KMSKA; Hannibal, 2024), fig . 42.',
#    'exhibition_history': 'Paris, Galerie Martinet, 1865, cat. 5.\n\nParis, Place de l’Alma, Exhibition Manet Particulière, May 1867, cat. 38.\n\nParis, Ecole Nationale des Beaux-Arts, Exposition des oeuvres d’Édouard Manet, Jan. 1884, cat. 31.\n\nParis, Exposition Internationale Universelle, Exposition Centennale de l’Art Français, 1880–1889, 1900, cat. 31.\n\nParis, Manzi, Joyant et Cie, Exposition d’art moderne, 1912, cat. 27.\n\nNew York, Durand-Ruel Gallery, Paintings by Édouard Manet, Nov. 29-Dec. 13, 1913, cat. 6.\n\nNew York, M. Knoedler & Co., Loan Exhibition of Old Masters, Nov. 29-Dec. 11, 1920, cat. 9.\n\nPittsburgh, Carnegie Institute, Paintings, Édouard Manet, Pierre Renoir, Berthe Morisot, Oct. 15-Dec. 1, 1924, cat. 37; Cleveland Museum of Art, Dec. 9, 1924-Jan. 15, 1925.\n\nCleveland Museum of Art, Catalogue of the Twentieth Anniversary Exhibition of the Cleveland Museum of Art: The Official Art Exhibit of the Great Lakes Exposition, June 26–Oct. 4, 1936, cat. 286.\n\nNew York, Wildenstein & Co., Édouard Manet: A Retrospective Exhibition for the Benefit of French Hospitals, Mar.–Apr. 1937, cat. 7.\n\nNew York, Wildenstein & Co., organized by Institute of Modern Art, The Sources of Modern Painting, Apr.–May 1939, cat. 9a (ill.).\n\nNew York, World’s Fair, Masterpieces of Art, May–October 1940, cat. 282 (ill.).\n\nThe Art Institute of Chicago, Masterpiece of the Month, Feb. 1944, no cat.\n\nPhiladelphia Museum of Art, Manet, Nov. 3–Dec. 11, 1965, cat. 95 (ill.); Art Institute of Chicago, Jan. 13-Feb. 19, 1966.\n\nNew York, Brooklyn Museum of Art, The Triumph of Realism, 1967, cat. 5; Richmond, VA, Museum of Fine Arts, Dec. 11, 1967–Jan. 14, 1968; San Francisco, Feb. 17–Mar. 31, 1968, cat. 5.\n\nAlbi, France, Musée Toulous-Lautrec, Trésors impressionists du musée de Chicago, June 27–Aug. 31, 1980, cat. 1 (ill.).\n\nParis, Galeies Nationales du Grand Palais, Manet (1832–1883), Apr. 22–Aug. 1, 1983, cat. 81 (ill.); New York, Metropolitan Museum of Art, Sep. 10–Nov. 27, 1983.\n\nCopenhagen, Ordrupgaard, Edouard Manet, Sep. 15-Dec. 10, 1989, cat. 8 (ill.).\n\nParis, Musée d’Orsay, Manet les natures mortes, Oct. 9, 2000-Jan. 7, 2001, cat. 17 (ill.); Baltimore, The Walters Art Gallery, Jan. 30-Apr. 22, 2001.\n\nThe Art Institute of Chicago, Manet and the Sea, Oct. 20, 2003-Jan. 19, 2004, no cat. no., pl. 18; Philadelphia Museum of Art, Feb. 15-May 30, 2004; Amsterdam, Van Gogh Museum, Amsterdam, June 18-Sep. 26, 2004.\n\nFort Worth, Tex., Kimbell Museum of Art, The Impressionists: Master Paintings from the Art Institute of Chicago, June 29–Nov. 2, 2008, cat. 1 (ill.).\n\nToledo, OH, Toledo Museum of Art, ONE EACH: Still Lifes by Pissarro, Cézanne, Manet, & Friends, Jan. 18-Apr. 12, 2020, no cat.; Cincinnati Art Museum, Mar. 11-May 8, 2022.\n\nAntwerp, Royal Museum of Fine Arts, In Your Wildest Dreams: James Ensor Beyond Impressionism, Sep. 27, 2024–Jan. 5, 2025, fig . 42.',
#    'provenance_text': 'The artist; possibly sold to Basset, Paris, 1867 [this and the following per emails from Juliet Wilson-Bareau to the Art Institute of Chicago, November 11, 2016 and April 24, 2017; copies in curatorial object file]; sold to Durand-Ruel, Paris, April 1872, for 250 francs [per Durand-Ruel, Paris, stock book for 1868–73 (no. 1228); copy of reference in curatorial object file]; possibly sold to Jean-Baptiste Faure (d. 1914), Paris, November 16, 1874, for 1,500 francs. Félix Gérard, Paris, by 1884 [lent to Paris, 1884, cat. 31]. Galerie Manzi-Joyant, Paris, by 1900 [Paris, 1900, cat. 449, p. 210]. John W. Simpson (d. 1920), New York, by November 22, 1913 [Simpson placed the picture on deposit at Durand-Ruel, New York (deposit no. 7731) on that day until December 23, 1913]; by descent to Mrs. John W. Simpson (née Kate Seney), New York, 1920; Knoedler and Co., New York, April 18, 1942 [M. Knoedler and Co., New York, Commission Book 3, Getty Research Institute Research Library, Los Angeles]; sold to the Art Institute of Chicago, July 1942.',
#    'edition': None,
#    'publishing_verification_level': 'Web Cataloged',
#    'internal_department_id': 14,
#    'fiscal_year': 1943,
#    'fiscal_year_deaccession': None,
#    'is_public_domain': True,
#    'is_zoomable': True,
#    'max_zoom_window_size': -1,
#    'copyright_notice': None,
#    'has_multimedia_resources': True,
#    'has_educational_resources': False,
#    'has_advanced_imaging': False,
#    'colorfulness': 0,
#    'color': {'h': 52,
#     'l': 47,
#     's': 62,
#     'percentage': 0.006925650478402625,
#     'population': 39},
#    'latitude': None,
#    'longitude': None,
#    'latlon': None,
#    'is_on_view': False,
#    'on_loan_display': None,
#    'gallery_title': None,
#    'gallery_id': None,
#    'nomisma_id': None,
#    'artwork_type_title': 'Painting',
#    'artwork_type_id': 1,
#    'department_title': 'Painting and Sculpture of Europe',
#    'department_id': 'PC-10',
#    'artist_id': 35577,
#    'artist_title': 'Édouard Manet',
#    'alt_artist_ids': [],
#    'artist_ids': [35577],
#    'artist_titles': ['Édouard Manet'],
#    'category_ids': ['PC-10', 'PC-831'],
#    'category_titles': ['Painting and Sculpture of Europe', 'Essentials'],
#    'term_titles': ['oil on canvas',
#     '19th century',
#     'oil painting',
#     'oil paint (paint)',
#     'still life',
#     'tablecloth',
#     'table',
#     'pot',
#     'knife',
#     'nineteenth century',
#     'Impressionism',
#     'painting techniques',
#     'painting',
#     'painting',
#     'paint',
#     'paint',
#     'oil paintings (visual works)',
#     'french',
#     'still life',
#     'painting (image making)',
#     'canvas',
#     'painting',
#     'european painting',
#     'kitchenware',
#     'death',
#     'food',
#     'eels',
#     'fruit',
#     'lemons',
#     'oysters',
#     'fish'],
#    'style_id': 'TM-13203',
#    'style_title': '19th century',
#    'alt_style_ids': ['TM-15636', 'TM-7543'],
#    'style_ids': ['TM-13203', 'TM-15636', 'TM-7543'],
#    'style_titles': ['19th century', 'nineteenth century', 'Impressionism'],
#    'classification_id': 'TM-66',
#    'classification_title': 'oil on canvas',
#    'alt_classification_ids': ['TM-10387',
#     'TM-78',
#     'TM-14976',
#     'TM-15338',
#     'TM-9',
#     'TM-54'],
#    'classification_ids': ['TM-66',
#     'TM-10387',
#     'TM-78',
#     'TM-14976',
#     'TM-15338',
#     'TM-9',
#     'TM-54'],
#    'classification_titles': ['oil on canvas',
#     'paint',
#     'oil paintings (visual works)',
#     'french',
#     'still life',
#     'painting',
#     'european painting'],
#    'subject_id': 'TM-8937',
#    'alt_subject_ids': ['TM-15423',
#     'TM-14175',
#     'TM-14523',
#     'TM-15434',
#     'TM-12517',
#     'TM-12097',
#     'TM-8673',
#     'TM-12819',
#     'TM-11204',
#     'TM-12818',
#     'TM-12817',
#     'TM-9135'],
#    'subject_ids': ['TM-8937',
#     'TM-15423',
#     'TM-14175',
#     'TM-14523',
#     'TM-15434',
#     'TM-12517',
#     'TM-12097',
#     'TM-8673',
#     'TM-12819',
#     'TM-11204',
#     'TM-12818',
#     'TM-12817',
#     'TM-9135'],
#    'subject_titles': ['still life',
#     'tablecloth',
#     'table',
#     'pot',
#     'knife',
#     'kitchenware',
#     'death',
#     'food',
#     'eels',
#     'fruit',
#     'lemons',
#     'oysters',
#     'fish'],
#    'material_id': 'TM-2451',
#    'alt_material_ids': ['TM-13502', 'TM-2577', 'TM-3124'],
#    'material_ids': ['TM-2451', 'TM-13502', 'TM-2577', 'TM-3124'],
#    'material_titles': ['oil paint (paint)', 'painting', 'paint', 'canvas'],
#    'technique_id': 'TM-4273',
#    'alt_technique_ids': ['TM-3971', 'TM-14210', 'TM-3891'],
#    'technique_ids': ['TM-4273', 'TM-3971', 'TM-14210', 'TM-3891'],
#    'technique_titles': ['oil painting',
#     'painting techniques',
#     'painting',
#     'painting (image making)'],
#    'theme_titles': ['Essentials'],
#    'image_id': '0cbe27e8-2fec-3445-bc48-ce40a8f2dc25',
#    'alt_image_ids': [],
#    'document_ids': [],
#    'sound_ids': [],
#    'video_ids': [],
#    'text_ids': [],
#    'section_ids': [39213441156],
#    'section_titles': ['Cat. 2 \xa0Fish (Still Life), 1864'],
#    'site_ids': [],
#    'suggest_autocomplete_boosted': 'Fish (Still Life)',
#    'suggest_autocomplete_all': [{'input': ['1942.311'],
#      'contexts': {'groupings': ['accession']}},
#     {'input': ['Fish (Still Life)'],
#      'weight': 16122,
#      'contexts': {'groupings': ['title']}}],
#    'source_updated_at': '2026-02-17T12:30:54-06:00',
#    'updated_at': '2026-02-17T12:35:28-06:00',
#    'timestamp': '2026-02-17T13:05:47-06:00'},
#   {'id': 81519,
#    'api_model': 'artworks',
#    'api_link': 'https://api.artic.edu/api/v1/artworks/81519',
#    'is_boosted': False,
#    'title': 'Young Woman',
#    'alt_titles': None,
#    'thumbnail': {'lqip': '...',
#     'width': 2724,
#     'height': 2250,
#     'alt_text': 'A work made of oil on canvas.'},
#    'main_reference_number': '1922.415',
#    'has_not_been_viewed_much': False,
#    'boost_rank': None,
#    'date_start': 1844,
#    'date_end': 1845,
#    'date_display': '1844–45',
#    'date_qualifier_title': '',
#    'date_qualifier_id': None,
#    'artist_display': 'Jean-François Millet (French, 1814–1875)',
#    'place_of_origin': 'France',
#    'description': None,
#    'short_description': None,
#    'dimensions': '52.1 × 62.4 cm (20 1/2 × 24 1/2 in.); Framed: 66.7 × 79.1 × 7.7 cm (26 1/4 × 31 1/8 × 3 in.)',
#    'dimensions_detail': [{'depth': None,
#      'width': 62,
#      'height': 52,
#      'diameter': None,
#      'clarification': None},
#     {'depth': 7,
#      'width': 79,
#      'height': 66,
#      'diameter': None,
#      'clarification': 'Framed'}],
#    'medium_display': 'Oil on canvas',
#    'inscriptions': None,
#    'credit_line': 'Potter Palmer Collection',
#    'catalogue_display': None,
#    'publication_history': None,
#    'exhibition_history': None,
#    'provenance_text': None,
#    'edition': None,
#    'publishing_verification_level': 'Web Basic',
#    'internal_department_id': 14,
#    'fiscal_year': 1922,
#    'fiscal_year_deaccession': None,
#    'is_public_domain': True,
#    'is_zoomable': True,
#    'max_zoom_window_size': -1,
#    'copyright_notice': None,
#    'has_multimedia_resources': False,
#    'has_educational_resources': False,
#    'has_advanced_imaging': False,
#    'colorfulness': 32.4745,
#    'color': {'h': 37,
#     'l': 53,
#     's': 29,
#     'percentage': 0.05232407521031892,
#     'population': 307},
#    'latitude': None,
#    'longitude': None,
#    'latlon': None,
#    'is_on_view': True,
#    'on_loan_display': None,
#    'gallery_title': 'Gallery 222',
#    'gallery_id': 2147483607,
#    'nomisma_id': None,
#    'artwork_type_title': 'Painting',
#    'artwork_type_id': 1,
#    'department_title': 'Painting and Sculpture of Europe',
#    'department_id': 'PC-10',
#    'artist_id': 35787,
#    'artist_title': 'Jean François Millet',
#    'alt_artist_ids': [],
#    'artist_ids': [35787],
#    'artist_titles': ['Jean François Millet'],
#    'category_ids': ['PC-10'],
#    'category_titles': ['Painting and Sculpture of Europe'],
#    'term_titles': ['oil on canvas',
#     'woman',
#     'oil painting',
#     'oil paint (paint)',
#     'nineteenth century',
#     'youth',
#     'window',
#     'white (color)',
#     'headdresses',
#     'girl',
#     'painting techniques',
#     'painting (image making)',
#     'painting',
#     'painting',
#     'paint',
#     'canvas',
#     'paint',
#     'oil paintings (visual works)',
#     'french',
#     'Barbizon School',
#     '19th century',
#     'painting',
#     'european painting'],
#    'style_id': 'TM-15636',
#    'style_title': 'nineteenth century',
#    'alt_style_ids': ['TM-12026', 'TM-13203'],
#    'style_ids': ['TM-15636', 'TM-12026', 'TM-13203'],
#    'style_titles': ['nineteenth century', 'Barbizon School', '19th century'],
#    'classification_id': 'TM-66',
#    'classification_title': 'oil on canvas',
#    'alt_classification_ids': ['TM-10387',
#     'TM-78',
#     'TM-14976',
#     'TM-9',
#     'TM-54'],
#    'classification_ids': ['TM-66',
#     'TM-10387',
#     'TM-78',
#     'TM-14976',
#     'TM-9',
#     'TM-54'],
#    'classification_titles': ['oil on canvas',
#     'paint',
#     'oil paintings (visual works)',
#     'french',
#     'painting',
#     'european painting'],
#    'subject_id': 'TM-13813',
#    'alt_subject_ids': ['TM-12198',
#     'TM-14921',
#     'TM-11841',
#     'TM-12425',
#     'TM-15436'],
#    'subject_ids': ['TM-13813',
#     'TM-12198',
#     'TM-14921',
#     'TM-11841',
#     'TM-12425',
#     'TM-15436'],
#    'subject_titles': ['woman',
#     'youth',
#     'window',
#     'white (color)',
#     'headdresses',
#     'girl'],
#    'material_id': 'TM-2451',
#    'alt_material_ids': ['TM-13502', 'TM-2577', 'TM-3124'],
#    'material_ids': ['TM-2451', 'TM-13502', 'TM-2577', 'TM-3124'],
#    'material_titles': ['oil paint (paint)', 'painting', 'paint', 'canvas'],
#    'technique_id': 'TM-4273',
#    'alt_technique_ids': ['TM-3971', 'TM-3891', 'TM-14210'],
#    'technique_ids': ['TM-4273', 'TM-3971', 'TM-3891', 'TM-14210'],
#    'technique_titles': ['oil painting',
#     'painting techniques',
#     'painting (image making)',
#     'painting'],
#    'theme_titles': [],
#    'image_id': '681c9b51-6682-3f8c-dac8-ad250ed82240',
#    'alt_image_ids': [],
#    'document_ids': [],
#    'sound_ids': [],
#    'video_ids': [],
#    'text_ids': [],
#    'section_ids': [],
#    'section_titles': [],
#    'site_ids': [],
#    'suggest_autocomplete_all': [{'input': ['1922.415'],
#      'contexts': {'groupings': ['accession']}},
#     {'input': ['Young Woman'],
#      'weight': 1138,
#      'contexts': {'groupings': ['title']}}],
#    'source_updated_at': '2026-02-17T12:31:15-06:00',
#    'updated_at': '2026-02-17T12:35:27-06:00',
#    'timestamp': '2026-02-17T13:05:47-06:00'},
#   {'id': 86723,
#    'api_model': 'artworks',
#    'api_link': 'https://api.artic.edu/api/v1/artworks/86723',
#    'is_boosted': False,
#    'title': 'Three Hissing Geese',
#    'alt_titles': None,
#    'thumbnail': {'lqip': '...',
#     'width': 1886,
#     'height': 2250,
#     'alt_text': 'A work made of bronze.'},
#    'main_reference_number': '1931.939',
#    'has_not_been_viewed_much': True,
#    'boost_rank': None,
#    'date_start': 1929,
#    'date_end': 1929,
#    'date_display': '1929',
#    'date_qualifier_title': '',
#    'date_qualifier_id': None,
#    'artist_display': 'Heinz Warneke (American, born Germany, 1895–1983)',
#    'place_of_origin': 'United States',
#    'description': None,
#    'short_description': None,
#    'dimensions': '23.5 × 33.7 × 36.5 cm (9 1/4 × 13 3/4 × 14 3/8 in.) (with base)',
#    'dimensions_detail': [],
#    'medium_display': 'Bronze',
#    'inscriptions': 'Signed, rear of base: "H. Warneke/1929"',
#    'credit_line': 'Gift of Charles H. Worcester',
#    'catalogue_display': None,
#    'publication_history': None,
#    'exhibition_history': 'Art Institute of Chicago, A Century of Progress, June 1–Nov. 1, 1933, cat. 1218.\n\nArt Institute of Chicago, A Century of Progress, June 1–Nov. 1, 1934, cat. 839.',
#    'provenance_text': None,
#    'edition': None,
#    'publishing_verification_level': 'Web Cataloged',
#    'internal_department_id': 21,
#    'fiscal_year': 1932,
#    'fiscal_year_deaccession': None,
#    'is_public_domain': False,
#    'is_zoomable': False,
#    'max_zoom_window_size': 843,
#    'copyright_notice': None,
#    'has_multimedia_resources': False,
#    'has_educational_resources': False,
#    'has_advanced_imaging': False,
#    'colorfulness': 2.2445,
#    'color': {'h': 240,
#     'l': 56,
#     's': 0,
#     'percentage': 0.2379554228602289,
#     'population': 2018},
#    'latitude': None,
#    'longitude': None,
#    'latlon': None,
#    'is_on_view': False,
#    'on_loan_display': None,
#    'gallery_title': None,
#    'gallery_id': None,
#    'nomisma_id': None,
#    'artwork_type_title': 'Sculpture',
#    'artwork_type_id': 3,
#    'department_title': 'Arts of the Americas',
#    'department_id': 'PC-3',
#    'artist_id': 27982,
#    'artist_title': 'Heinz Warneke',
#    'alt_artist_ids': [],
#    'artist_ids': [27982],
#    'artist_titles': ['Heinz Warneke'],
#    'category_ids': ['PC-3'],
#    'category_titles': ['Arts of the Americas'],
#    'term_titles': ['sculpture',
#     'bronze',
#     'Century of Progress',
#     'modern and contemporary art',
#     "world's fairs",
#     "Chicago World's Fairs"],
#    'style_id': None,
#    'style_title': None,
#    'alt_style_ids': [],
#    'style_ids': [],
#    'style_titles': [],
#    'classification_id': 'TM-13',
#    'classification_title': 'sculpture',
#    'alt_classification_ids': ['TM-155'],
#    'classification_ids': ['TM-13', 'TM-155'],
#    'classification_titles': ['sculpture', 'modern and contemporary art'],
#    'subject_id': 'TM-12169',
#    'alt_subject_ids': ['TM-11299', 'TM-12176'],
#    'subject_ids': ['TM-12169', 'TM-11299', 'TM-12176'],
#    'subject_titles': ['Century of Progress',
#     "world's fairs",
#     "Chicago World's Fairs"],
#    'material_id': 'TM-2430',
#    'alt_material_ids': [],
#    'material_ids': ['TM-2430'],
#    'material_titles': ['bronze'],
#    'technique_id': None,
#    'alt_technique_ids': [],
#    'technique_ids': [],
#    'technique_titles': [],
#    'theme_titles': [],
#    'image_id': 'c06643ea-a222-5c4b-33fc-c3556f8e9f6f',
#    'alt_image_ids': [],
#    'document_ids': [],
#    'sound_ids': [],
#    'video_ids': [],
#    'text_ids': [],
#    'section_ids': [],
#    'section_titles': [],
#    'site_ids': [],
#    'suggest_autocomplete_all': [{'input': ['1931.939'],
#      'contexts': {'groupings': ['accession']}},
#     {'input': ['Three Hissing Geese'],
#      'weight': 31,
#      'contexts': {'groupings': ['title']}}],
#    'source_updated_at': '2026-02-17T12:27:15-06:00',
#    'updated_at': '2026-02-17T12:30:35-06:00',
#    'timestamp': '2026-02-17T13:05:47-06:00'},
#   {'id': 12624,
#    'api_model': 'artworks',
#    'api_link': 'https://api.artic.edu/api/v1/artworks/12624',
#    'is_boosted': False,
#    'title': 'Jeff',
#    'alt_titles': None,
#    'thumbnail': {'lqip': '...',
#     'width': 2031,
#     'height': 2250,
#     'alt_text': 'A work made of bronze.'},
#    'main_reference_number': '1932.968',
#    'has_not_been_viewed_much': False,
#    'boost_rank': None,
#    'date_start': 1932,
#    'date_end': 1932,
#    'date_display': '1932',
#    'date_qualifier_title': '',
#    'date_qualifier_id': None,
#    'artist_display': 'Maeble Perry Edwards (American, 1897–1981)',
#    'place_of_origin': 'United States',
#    'description': None,
#    'short_description': None,
#    'dimensions': 'H.: 23.5 cm (9 1/4 in.); Base: 14 × 6.4 cm (5 1/2 × 2 1/2 in.)',
#    'dimensions_detail': [{'depth': None,
#      'width': None,
#      'height': 23,
#      'diameter': None,
#      'clarification': None},
#     {'depth': None,
#      'width': 6,
#      'height': 14,
#      'diameter': None,
#      'clarification': 'Base'}],
#    'medium_display': 'Bronze',
#    'inscriptions': 'Signed: "Maeble C. Perry" on base',
#    'credit_line': 'Gift of Charles H. Worcester',
#    'catalogue_display': None,
#    'publication_history': 'Art Institute of Chicago, <em>Catalogue of the Thirty-Sixth Annual Exhibition by Artists of Chicago and Vicinity</em>, exh. cat. (Art Institute of Chicago, 1932), n.p., cat. 236.\n\nArt Institute of Chicago, <em>Catalogue of a Century of Progress: Exhibition of Paintings and Sculpture, Lent from American Collections</em>, exh. cat. (Art Institute of Chicago, 1933), 111, cat. 1183.',
#    'exhibition_history': 'Art Institute of Chicago, <a href="https://www.artic.edu/exhibitions/5564/chicago-and-vicinity-36th-annual"><em>Thirty–Sixth Annual Exhibition by Artists of Chicago and Vicinity</em></a>, Jan. 28–Mar. 20, 1932, cat. 236.\n\nArt Institute of Chicago, <a href="https://www.artic.edu/exhibitions/5626/a-century-of-progress-loan-exhibition-of-paintings-and-sculpture-1933"><em>A Century of Progress: Exhibition of Paintings and Sculpture</em></a>, June 1–Nov. 1, 1933, cat. 1183.',
#    'provenance_text': 'The artist; sold to Charles H. Worcester, Chicago, 1932; given to the Art Institute of Chicago, 1932.',
#    'edition': None,
#    'publishing_verification_level': 'Web Cataloged',
#    'internal_department_id': 21,
#    'fiscal_year': 1932,
#    'fiscal_year_deaccession': None,
#    'is_public_domain': False,
#    'is_zoomable': False,
#    'max_zoom_window_size': 843,
#    'copyright_notice': None,
#    'has_multimedia_resources': False,
#    'has_educational_resources': False,
#    'has_advanced_imaging': False,
#    'colorfulness': 8.9463,
#    'color': {'h': 306,
#     'l': 53,
#     's': 0,
#     'percentage': 0.3288195264694004,
#     'population': 2589},
#    'latitude': None,
#    'longitude': None,
#    'latlon': None,
#    'is_on_view': False,
#    'on_loan_display': None,
#    'gallery_title': None,
#    'gallery_id': None,
#    'nomisma_id': None,
#    'artwork_type_title': 'Sculpture',
#    'artwork_type_id': 3,
#    'department_title': 'Arts of the Americas',
#    'department_id': 'PC-3',
#    'artist_id': 7502,
#    'artist_title': 'Maeble Perry Edwards',
#    'alt_artist_ids': [],
#    'artist_ids': [7502],
#    'artist_titles': ['Maeble Perry Edwards'],
#    'category_ids': ['PC-825', 'PC-3'],
#    'category_titles': ['Women artists', 'Arts of the Americas'],
#    'term_titles': ['sculpture',
#     'bronze',
#     'Century of Progress',
#     'modern and contemporary art',
#     "world's fairs",
#     "Chicago World's Fairs"],
#    'style_id': None,
#    'style_title': None,
#    'alt_style_ids': [],
#    'style_ids': [],
#    'style_titles': [],
#    'classification_id': 'TM-13',
#    'classification_title': 'sculpture',
#    'alt_classification_ids': ['TM-155'],
#    'classification_ids': ['TM-13', 'TM-155'],
#    'classification_titles': ['sculpture', 'modern and contemporary art'],
#    'subject_id': 'TM-12169',
#    'alt_subject_ids': ['TM-11299', 'TM-12176'],
#    'subject_ids': ['TM-12169', 'TM-11299', 'TM-12176'],
#    'subject_titles': ['Century of Progress',
#     "world's fairs",
#     "Chicago World's Fairs"],
#    'material_id': 'TM-2430',
#    'alt_material_ids': [],
#    'material_ids': ['TM-2430'],
#    'material_titles': ['bronze'],
#    'technique_id': None,
#    'alt_technique_ids': [],
#    'technique_ids': [],
#    'technique_titles': [],
#    'theme_titles': ['Women artists'],
#    'image_id': '42e76859-a229-4404-04eb-2ae66a8b01cb',
#    'alt_image_ids': [],
#    'document_ids': [],
#    'sound_ids': [],
#    'video_ids': [],
#    'text_ids': [],
#    'section_ids': [],
#    'section_titles': [],
#    'site_ids': [],
#    'suggest_autocomplete_all': [{'input': ['1932.968'],
#      'contexts': {'groupings': ['accession']}},
#     {'input': ['Jeff'], 'weight': 245, 'contexts': {'groupings': ['title']}}],
#    'source_updated_at': '2026-02-17T12:23:02-06:00',
#    'updated_at': '2026-02-17T12:25:28-06:00',
#    'timestamp': '2026-02-17T13:05:47-06:00'}],
#  'info': {'license_text': 'The `description` field in this response is licensed under a Creative Commons Attribution 4.0 Generic License (CC-By) and the Terms and Conditions of artic.edu. All other data in this response is licensed under a Creative Commons Zero (CC0) 1.0 designation and the Terms and Conditions of artic.edu.',
#   'license_links': ['https://creativecommons.org/publicdomain/zero/1.0/',
#    'https://www.artic.edu/terms'],
#   'version': '1.13'},
#  'config': {'iiif_url': 'https://www.artic.edu/iiif/2',
#   'website_url': 'http://www.artic.edu'}}

# %%
import pandas as pd
df=pd.json_normalize(data['data'])
df
# Out:
#         id api_model                                      api_link  \
# 0   282463  artworks  https://api.artic.edu/api/v1/artworks/282463
# 1   283047  artworks  https://api.artic.edu/api/v1/artworks/283047
# 2   283046  artworks  https://api.artic.edu/api/v1/artworks/283046
# 3   190181  artworks  https://api.artic.edu/api/v1/artworks/190181
# 4   212578  artworks  https://api.artic.edu/api/v1/artworks/212578
# 5   212576  artworks  https://api.artic.edu/api/v1/artworks/212576
# 6   278628  artworks  https://api.artic.edu/api/v1/artworks/278628
# 7   278593  artworks  https://api.artic.edu/api/v1/artworks/278593
# 8    44892  artworks   https://api.artic.edu/api/v1/artworks/44892
# 9    81519  artworks   https://api.artic.edu/api/v1/artworks/81519
# 10   86723  artworks   https://api.artic.edu/api/v1/artworks/86723
# 11   12624  artworks   https://api.artic.edu/api/v1/artworks/12624
#
#     is_boosted                                              title alt_titles  \
# 0        False          Expressions 1 (A Study of Facial Motions)       None
# 1        False                        Ten Projects for Staircases       None
# 2        False          Gestures #1 (A Study of Finger Positions)       None
# 3        False  River City II, Chicago, Illinois, Perspective ...       None
# 4        False           River City I: Pedestrian Park Level Plan       None
# 5        False                River City I: Industrial Level Plan       None
# 6        False            Untitled (Jinete with Red Shirt No. 3)​       None
# 7        False     Untitled (Two Figures, Female Figure Pointing)       None
# 8         True                                  Fish (Still Life)       None
# 9        False                                        Young Woman       None
# 10       False                                Three Hissing Geese       None
# 11       False                                               Jeff       None
#
#     thumbnail main_reference_number  has_not_been_viewed_much boost_rank  ...  \
# 0         NaN              2025.914                      True       None  ...
# 1         NaN              2025.921                      True       None  ...
# 2         NaN              2025.920                      True       None  ...
# 3         NaN       RX23664/110.283                     False       None  ...
# 4         NaN       RX23664/110.198                      True       None  ...
# 5         NaN       RX23664/110.195                      True       None  ...
# 6         NaN             2025.1002                      True       None  ...
# 7         NaN             2025.1003                      True       None  ...
# 8         NaN              1942.311                     False       None  ...
# 9         NaN              1922.415                     False       None  ...
# 10        NaN              1931.939                      True       None  ...
# 11        NaN              1932.968                     False       None  ...
#
#                                        thumbnail.lqip  thumbnail.width  \
# 0                                                 NaN              NaN
# 1                                                 NaN              NaN
# 2                                                 NaN              NaN
# 3   ......           5160.0
# 4   ......           3000.0
# 5   ......           3000.0
# 6   ......           8320.0
# 7   ......           8323.0
# 8   ......          16704.0
# 9   ......           2724.0
# 10  ......           1886.0
# 11  ......           2031.0
#
#    thumbnail.height                                 thumbnail.alt_text  \
# 0               NaN                                                NaN
# 1               NaN                                                NaN
# 2               NaN                                                NaN
# 3            3135.0            A work made of marker on tracing paper.
# 4            1685.0  A work made of zip-a-tone, colored pencil, fil...
# 5            1784.0  A work made of zip-a-tone, colored pencil, fil...
# 6            9906.0  A work made of graphite, tempera, and crayon o...
# 7            9518.0  A work made of graphite and opaque watercolor ...
# 8           13234.0  Still-life painting, fish, open oysters, eel, ...
# 9            2250.0                      A work made of oil on canvas.
# 10           2250.0                             A work made of bronze.
# 11           2250.0                             A work made of bronze.
#
#     color.h color.l color.s color.percentage color.population  \
# 0       NaN     NaN     NaN              NaN              NaN
# 1       NaN     NaN     NaN              NaN              NaN
# 2       NaN     NaN     NaN              NaN              NaN
# 3      38.0    47.0     8.0         0.759240           3277.0
# 4      45.0    55.0    84.0         0.059187            236.0
# 5      23.0    50.0    87.0         0.004972             21.0
# 6       6.0    53.0    19.0         0.000488            402.0
# 7       5.0    42.0    39.0         0.000114             90.0
# 8      52.0    47.0    62.0         0.006926             39.0
# 9      37.0    53.0    29.0         0.052324            307.0
# 10    240.0    56.0     0.0         0.237955           2018.0
# 11    306.0    53.0     0.0         0.328820           2589.0
#
#    suggest_autocomplete_boosted
# 0                           NaN
# 1                           NaN
# 2                           NaN
# 3                           NaN
# 4                           NaN
# 5                           NaN
# 6                           NaN
# 7                           NaN
# 8             Fish (Still Life)
# 9                           NaN
# 10                          NaN
# 11                          NaN
#
# [12 rows x 108 columns]

# %%
df[['api_link','is_boosted']]
# Out:
#                                         api_link  is_boosted
# 0   https://api.artic.edu/api/v1/artworks/282463       False
# 1   https://api.artic.edu/api/v1/artworks/283047       False
# 2   https://api.artic.edu/api/v1/artworks/283046       False
# 3   https://api.artic.edu/api/v1/artworks/190181       False
# 4   https://api.artic.edu/api/v1/artworks/212578       False
# 5   https://api.artic.edu/api/v1/artworks/212576       False
# 6   https://api.artic.edu/api/v1/artworks/278628       False
# 7   https://api.artic.edu/api/v1/artworks/278593       False
# 8    https://api.artic.edu/api/v1/artworks/44892        True
# 9    https://api.artic.edu/api/v1/artworks/81519       False
# 10   https://api.artic.edu/api/v1/artworks/86723       False
# 11   https://api.artic.edu/api/v1/artworks/12624       False

# %% [markdown]
# homework

# %%
url2="https://nekos.best/api/v2/neko"
res2=requests.get(url2)

# %%
data=res2.json()
data
# Out:
# {'results': [{'artist_name': 'Sana ☽*.ﾟ',
#    'artist_href': 'https://twitter.com/sanamaru_0w0',
#    'source_url': 'https://twitter.com/sanamaru_0w0/',
#    'url': 'https://nekos.best/api/v2/neko/64066e3a-4e33-4c98-b8dc-764006aca307.png'}]}

# %%
import xml.etree.ElementTree as ET

url3="https://api.waifu.pics/nsfw/waifu"

for i in range(5):
 res3=requests.get(url3)

 data=res3.json()
 print(data)
# Out:
# {'url': 'https://i.waifu.pics/TxIA-tu.com_0364.jpg'}
# {'url': 'https://i.waifu.pics/M0~C7jF.jpg'}
# {'url': 'https://i.waifu.pics/N3RRr1I.com_0135.jpg'}
# {'url': 'https://i.waifu.pics/hdRB5dc.com_0165.jpg'}
# {'url': 'https://i.waifu.pics/U7xWbR6.png'}

# %%
url = "https://api.waifu.pics/nsfw/waifu"

response = requests.get(url)
image_url = response.json()["url"]

img_data = requests.get(image_url).content

with open("image.jpg", "wb") as f:
    f.write(img_data)

print("Saved image.jpg")


import requests

url = "https://api.waifu.pics/nsfw/waifu"

for i in range(5):
    # Get JSON from API
    response = requests.get(url)
    image_url = response.json()["url"]

    # Download image
    img_data = requests.get(image_url).content

    # Save with unique name
    filename = f"image_{i+1}.jpg"

    with open(filename, "wb") as f:
        f.write(img_data)

    print(f"Saved {filename}")
# Out:
# Saved image.jpg

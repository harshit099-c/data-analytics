# %%
#Melt & Pivot

import pandas as pd

df_copy=pd.read_csv('raw_data.csv')
df_copy['Name']=df_copy['Name'].bfill(inplace=True)
df_copy=df_copy.reset_index(drop=True)
df_copy.to_csv('raw_data.csv')
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_10568\3261842251.py:6: ChainedAssignmentError: A value is being set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# Such inplace method never works to update the original DataFrame or Series, because the intermediate object on which we are setting values always behaves as a copy (due to Copy-on-Write).
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' instead, to perform the operation inplace on the original object, or try to avoid an inplace operation using 'df[col] = df[col].method(value)'.
#
# See the documentation for a more detailed explanation: https://pandas.pydata.org/pandas-docs/stable/user_guide/copy_on_write.html
#   df_copy['Name']=df_copy['Name'].bfill(inplace=True)

# %%
#melt and pivot
melted_df=df_copy.melt(        #expand data in rows
    id_vars=['Name','Id'],
    value_vars=['Salary','Salary_in_hand'],
    var_name='metrics',
    value_name='value'
)

melted_df.pivot( #expand in columns or back from melt
    index=['Name','Id'],
    columns='metrics',
    values='value'
)
# Out:
# metrics          Salary  Salary_in_hand
# Name         Id
# Ahmed Khan   6    73000           58400
#              7    68000           54400
# Alex         3    47000           37600
# Carlos Ruiz  9    45000           36000
# Emily Davis  10   58000           46400
# Jane Smith   2    62000           49600
# John Doe     1    55000           44000
# Li Wei       5    51000           40800
# Maria Garcia 4    45000           36000
# Rachel Lee   8    62000           49600

# %%
#Merging and Joining
df_customers=pd.DataFrame({
    'cust_id':[1,2,3,4],
    'cust_name':['Harshit','Hua','Ksj','Gss']

})

df_orders=pd.DataFrame({
    'order_id':[101,102,103,104],
    'amount':[200,300,399,400],
    'cust_id':[2,1,4,5]
})

# %%
#inner join

pd.merge(df_customers,df_orders,on='cust_id')
pd.merge(df_customers,df_orders,on='cust_id',how='left')
pd.merge(df_customers,df_orders,on='cust_id',how='right')
pd.merge(df_customers,df_orders,on='cust_id',how='outer') #union
# Out:
#    cust_id cust_name  order_id  amount
# 0        1   Harshit     102.0   300.0
# 1        2       Hua     101.0   200.0
# 2        3       Ksj       NaN     NaN
# 3        4       Gss     103.0   399.0
# 4        5       NaN     104.0   400.0

# %%
#data concatenation

pd.concat([df_customers,df_orders]) #rowise concat

#to reset row labels
pd.concat([df_customers,df_orders],ignore_index=True)

#columnwise concat
pd.concat([df_customers,df_orders],axis=1)
# Out:
#    Unnamed: 0.3  Unnamed: 0.2  Unnamed: 0.1  Unnamed: 0          Name  Age  \
# 0             0             0             0           0    Ahmed Khan   45
# 1             1             1             1           1    Ahmed Khan   38
# 2             2             2             2           2    Rachel Lee   29
# 3             3             3             3           3    Jane Smith   29
# 4             4             4             4           4   Emily Davis   31
# 5             5             5             5           5      John Doe   29
# 6             6             6             6           6        Li Wei   27
# 7             7             7             7           7          Alex   27
# 8             8             8             8           8   Carlos Ruiz   27
# 9             9             9             9           9  Maria Garcia   34
#
#   Country Gender  Salary  Tax(in %)  Salary_in_hand  Rank  Id
# 0      IN      F   73000         20           58400     1   6
# ...
